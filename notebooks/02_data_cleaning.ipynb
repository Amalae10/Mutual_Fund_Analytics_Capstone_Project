# %% [markdown]
# # 02 ? Data Cleaning
#
# This notebook documents the cleaning and validation stage of the Bluestock Mutual Fund Analytics ETL pipeline.

# %% [markdown]
# ## Objective
#
# - Clean NAV history data
# - Clean fund performance data
# - Clean investor transaction data
# - Validate AMFI codes
# - Save cleaned datasets to `data/processed/`

# %%
from pathlib import Path
import pandas as pd

RAW_DIR = Path('../data/raw')
PROCESSED_DIR = Path('../data/processed')

print('Raw directory:', RAW_DIR.resolve())
print('Processed directory:', PROCESSED_DIR.resolve())

# %%
print('Raw datasets:')
for file in sorted(RAW_DIR.glob('*.csv')):
    print('-', file.name)

# %%
print('Current processed datasets:')
for file in sorted(PROCESSED_DIR.glob('*.csv')):
    print('-', file.name)

# %% [markdown]
# ## NAV cleaning

# %%
# %run ../scripts/clean_nav.py

# %% [markdown]
# ## Fund performance cleaning

# %%
# %run ../scripts/clean_performance.py

# %% [markdown]
# ## Investor transaction cleaning

# %%
# %run ../scripts/clean_transactions.py

# %% [markdown]
# ## AMFI validation

# %%
# %run ../scripts/validate_amfi.py

# %% [markdown]
# ## Cleaning result
#
# The cleaned datasets are stored in `data/processed/` and are used by the subsequent EDA, performance analytics, advanced analytics, SQL, and Power BI stages.
